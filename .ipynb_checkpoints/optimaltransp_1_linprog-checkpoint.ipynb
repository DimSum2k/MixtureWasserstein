# %% [markdown]
# Optimal Transport with Linear Programming
# =========================================
#
# *Important:* Please read the [installation page](http://gpeyre.github.io/numerical-tours/installation_python/) for details about how to install the toolboxes.
# $\newcommand{\dotp}[2]{\langle #1, #2 \rangle}$
# $\newcommand{\enscond}[2]{\lbrace #1, #2 \rbrace}$
# $\newcommand{\pd}[2]{ \frac{ \partial #1}{\partial #2} }$
# $\newcommand{\umin}[1]{\underset{#1}{\min}\;}$
# $\newcommand{\umax}[1]{\underset{#1}{\max}\;}$
# $\newcommand{\umin}[1]{\underset{#1}{\min}\;}$
# $\newcommand{\uargmin}[1]{\underset{#1}{argmin}\;}$
# $\newcommand{\norm}[1]{\|#1\|}$
# $\newcommand{\abs}[1]{\left|#1\right|}$
# $\newcommand{\choice}[1]{ \left\{  \begin{array}{l} #1 \end{array} \right. }$
# $\newcommand{\pa}[1]{\left(#1\right)}$
# $\newcommand{\diag}[1]{{diag}\left( #1 \right)}$
# $\newcommand{\qandq}{\quad\text{and}\quad}$
# $\newcommand{\qwhereq}{\quad\text{where}\quad}$
# $\newcommand{\qifq}{ \quad \text{if} \quad }$
# $\newcommand{\qarrq}{ \quad \Longrightarrow \quad }$
# $\newcommand{\ZZ}{\mathbb{Z}}$
# $\newcommand{\CC}{\mathbb{C}}$
# $\newcommand{\RR}{\mathbb{R}}$
# $\newcommand{\EE}{\mathbb{E}}$
# $\newcommand{\Zz}{\mathcal{Z}}$
# $\newcommand{\Ww}{\mathcal{W}}$
# $\newcommand{\Vv}{\mathcal{V}}$
# $\newcommand{\Nn}{\mathcal{N}}$
# $\newcommand{\NN}{\mathcal{N}}$
# $\newcommand{\Hh}{\mathcal{H}}$
# $\newcommand{\Bb}{\mathcal{B}}$
# $\newcommand{\Ee}{\mathcal{E}}$
# $\newcommand{\Cc}{\mathcal{C}}$
# $\newcommand{\Gg}{\mathcal{G}}$
# $\newcommand{\Ss}{\mathcal{S}}$
# $\newcommand{\Pp}{\mathcal{P}}$
# $\newcommand{\Ff}{\mathcal{F}}$
# $\newcommand{\Xx}{\mathcal{X}}$
# $\newcommand{\Mm}{\mathcal{M}}$
# $\newcommand{\Ii}{\mathcal{I}}$
# $\newcommand{\Dd}{\mathcal{D}}$
# $\newcommand{\Ll}{\mathcal{L}}$
# $\newcommand{\Tt}{\mathcal{T}}$
# $\newcommand{\si}{\sigma}$
# $\newcommand{\al}{\alpha}$
# $\newcommand{\la}{\lambda}$
# $\newcommand{\ga}{\gamma}$
# $\newcommand{\Ga}{\Gamma}$
# $\newcommand{\La}{\Lambda}$
# $\newcommand{\si}{\sigma}$
# $\newcommand{\Si}{\Sigma}$
# $\newcommand{\be}{\beta}$
# $\newcommand{\de}{\delta}$
# $\newcommand{\De}{\Delta}$
# $\newcommand{\phi}{\varphi}$
# $\newcommand{\th}{\theta}$
# $\newcommand{\om}{\omega}$
# $\newcommand{\Om}{\Omega}$

# %% [markdown]
# This numerical tours details how to solve the discrete optimal transport
# problem (in the case of measures that are sums of Diracs) using linear
# programming.

# %% [markdown]
# You need to install [CVXPY](https://www.cvxpy.org/). _Warning:_ seems to not be working on Python 3.7, use rather 3.6.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cp
print(cp.__version__)
# Out:
# 1.0.25

# %% [markdown]
# Optimal Transport of Discrete Distributions
# ------------------------------------------
#
# We consider two dicretes distributions
# $$ \al = \sum_{i=1}^n a_i \de_{x_i} \qandq
#    \be = \sum_{j=1}^m b_j \de_{y_j}. $$
#
# where $n,m$ are the number of points, $\de_x$ is the Dirac at
# location $x \in \RR^d$, and $(x_i)_i, (y_j)_j$ are the positions of the diracs in $\RR^d$.

# %% [markdown]
# Dimensions $(n,m)$ of the coulds.

# %%
n = 60
m = 80

# %% [markdown]
# Generate the point clouds $X=(x_i)_i$ and $Y=(y_j)_j$.

# %%
gauss = lambda q,a,c: a*np.random.randn(2, q) + np.transpose(np.tile(c, (q,1)))

# Gaussian
X = np.random.randn(2,n)*.3
print(X.shape)

# Gaussian Mixture
Y = np.hstack((gauss(int(m/2),.5,[0,1.6]),np.hstack((gauss(int(m/4),.3,[-1,-1]),gauss(int(m/4),.3,[1,-1])))))
# Out:
# (2, 60)

# %% [markdown]
# Generate the weights $a,b$.

# %%
normalize = lambda a: a/np.sum(a)
a = normalize(np.random.rand(n, 1))
b = normalize(np.random.rand(m, 1))

# %% [markdown]
# Helper function for display of clouds.

# %%
myplot = lambda x,y,ms,col: plt.scatter(x,y, s=ms*20, edgecolors="k", c=col, linewidths=2)

# %% [markdown]
# Display the point clouds.
# The size of each dot is proportional to its probability density weight.

# %%
plt.figure(figsize = (10,7))
plt.axis("off")
for i in range(len(a)):
    myplot(X[0,i], X[1,i], a[i]*len(a)*10, 'b')
for j in range(len(b)):
    myplot(Y[0,j], Y[1,j], b[j]*len(b)*10, 'r')
plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
plt.show()

# %% [markdown]
# Compute the cost matrix $C_{i,j} := \norm{x_i-x_j}^2$.

# %%
def distmat(x,y):
    '''||x - y||^2 = ||x||^2 + ||y||^2 - 2<x,y>'''
    
    # Two ways of adding a dimension [:None] or .reshape(-1,1)
    return np.sum(x**2,0)[:,None] + np.sum(y**2,0).reshape(1,-1) - 2*x.transpose().dot(y)

C = distmat(X,Y)

# %% [markdown]
# Define the optimiztion variable $P$.

# %%
P = cp.Variable((n,m))

# %% [markdown]
# Define the set of discrete couplings between $\al$ and $\be$
# $$ U(a,b) := \enscond{ P \in \RR_+^{n \times m} }{
#      \forall i, \sum_j P_{i,j} = a_i, \:
#      \forall j, \sum_i P_{i,j} = b_j }. $$

# %%
u = np.ones((m,1))
v = np.ones((n,1))
U = [0 <= P, cp.matmul(P,u)==a, cp.matmul(P.T,v)==b]

# %% [markdown]
# The Kantorovitch formulation of the optimal transport reads
# $$ P^\star \in \uargmin{P \in U(a,b)} \sum_{i,j} P_{i,j} C_{i,j}.  $$
# Solve it using CVXPY

# %%
objective = cp.Minimize( cp.sum(cp.multiply(P,C)) )
prob = cp.Problem(objective, U)
result = prob.solve()

# %% [markdown]
# An optimal coupling $P^\star$ can be shown to be a sparse matrix
# with less than $n+m-1$ non zero entries. An entry $P_{i,j}^\star \neq 0$
# should be understood as a link between $x_{i}$
# and $y_{j}$ where an amount of mass equal to $P_{i,j}^\star$ is transfered.

# %% [markdown]
# Check that the number of non-zero entries in $P^\star$ is $n+m-1$. Beware that we are using an interior point method here, so that entries of $P^\star$ are nevery exactly 0.

# %%
print("Number of non-zero: %d (n + m-1 = %d)" %(len(P.value[P.value>1e-5]), n + m-1))
# Out:
# Number of non-zero: 137 (n + m-1 = 139)

# %% [markdown]
# Display the solution coupling.

# %%
plt.figure(figsize = (5,5))
plt.imshow(P.value);

# %% [markdown]
# Display the connexion defined by the optimal coupling.

# %%
I,J = np.nonzero(P.value>1e-5)
plt.figure(figsize = (10,7))
plt.axis('off')
for k in range(len(I)):
    h = plt.plot(np.hstack((X[0,I[k]],Y[0,J[k]])),np.hstack(([X[1,I[k]], Y[1,J[k]]])),'k', lw = 2)
for i in range(len(a)):
    myplot(X[0,i], X[1,i], a[i]*len(a)*10, 'b')
for j in range(len(b)):
    myplot(Y[0,j], Y[1,j], b[j]*len(b)*10, 'r')
plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
plt.show()

# %% [markdown]
# Displacement Interpolation
# --------------------------
# For any $t \in [0,1]$, one can define a distribution $\mu_t$ such
# that $t \mapsto \mu_t$ defines a geodesic for the Wasserstein metric.
#
#
# Since the $W_2$ distance is a geodesic distance, this geodesic path solves the
# following variational problem
#
# $$ \mu_t = \uargmin{\mu} (1-t)W_2(\al,\mu)^2 + t W_2(\be,\mu)^2. $$
# This can be understood as a generalization of the usual Euclidean
# barycenter to barycenter of distribution. Indeed, in the case that
# $\al = \de_{x}$ and $\be=\de_y$, one has $\mu_t=\de_{x_t}$ where $ x_t =
# (1-t)x+t y $.
#
#
# Once the optimal coupling $P^\star$ has been computed, the
# interpolated distribution is obtained as
#
# $$ \mu_t = \sum_{i,j} P^\star_{i,j} \de_{(1-t)x_{i} + t y_{j}}. $$

# %% [markdown]
# Find the $i,j$ with non-zero $P_{i,j}^\star$.

# %%
I,J = np.nonzero(P.value>1e-5)
Pij = P.value[I,J]

# %% [markdown]
# Display the evolution of $\mu_t$ for a varying value of $t \in [0,1]$.

# %%
plt.figure(figsize =(15,10))
tlist = np.linspace(0, 1, 6)
for i in range(len(tlist)):
    t = tlist[i]
    Xt = (1-t)*X[:,I] + t*Y[:,J]
    plt.subplot(2,3,i+1)
    plt.axis("off")
    for j in range(len(Pij)):
        myplot(Xt[0,j],Xt[1,j],Pij[j]*len(Pij)*6,[[t,0,1-t]])
    plt.title("t = %.1f" %t) 
    plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
    plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
plt.show()

# %%
def my_function(t=0):
    plt.figure(figsize =(40,15))
    
    Xt = (1-t)*X[:,I] + t*Y[:,J]
    plt.subplot(2,3,i+1)
    plt.axis("off")
    for j in range(len(Pij)):
        myplot(Xt[0,j],Xt[1,j],Pij[j]*len(Pij)*6,[[t,0,1-t]])
    plt.title("t = %.1f" %t) 
    plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
    plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
    
    plt.show()

    
tlist = np.linspace(0, 1, 6)
interact(my_function, t=(0., 1., 0.1))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0), Output()), _dom_classes=('widget-inter…
# <function __main__.my_function(t=0)>

# %% [markdown]
# Optimal Assignement
# -------------------
# In the case where $n=m$ and the weights are uniform $a_{i}=1/n, b_{j}=1/n$, one can show that there is at least one optimal transport coupling which is actually a
# permutation matrix. This properties comes from the fact that
# the extremal point of the polytope $U(1,1)$ are permutation matrices.
#
#
# This means that there exists an optimal permutation $\si^\star \in \Sigma_n$ such
# that
# $$ P^\star_{i,j} = \choice{
#       1 \qifq j=\si^\star(i), \\
#       0 \quad\text{otherwise}.
#   } $$
#
# where $\Si_n$ is the set of permutation (bijections) of
# $\{1,\ldots,n\}$.
#
#
# This permutation thus solves the so-called optimal assignement problem
# $$ \si^\star \in \uargmin{\si \in \Sigma_n}
#       \sum_{i} C_{i,\si(j)}. $$

# %% [markdown]
# Use the same number of points.

# %%
n = 40
m = n

# %% [markdown]
# Compute points clouds.

# %%
X = np.random.randn(2,n)*.3
Y = np.hstack((gauss(int(m/2),.5,[0,1.6]),np.hstack((gauss(int(m/4),.3,[-1,-1]),gauss(int(m/4),.3,[1,-1])))))

# %% [markdown]
# Constant distributions.

# %%
a = np.ones([n,1])/n
b = a

# %% [markdown]
# Compute the weight matrix $ (C_{i,j})_{i,j}. $

# %%
C = distmat(X,Y)

# %% [markdown]
# Display the coulds.

# %%
plt.figure(figsize = (10,7))
plt.axis('off')
myplot(X[0,:],X[1,:],10,'b')
myplot(Y[0,:],Y[1,:],10,'r')
plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
plt.show()

# %% [markdown]
# Solve the optimal transport.

# %%
P = cp.Variable((n,m))
u = np.ones((m,1))
v = np.ones((n,1))
U = [0 <= P, cp.matmul(P,u)==a, cp.matmul(P.T,v)==b]
objective = cp.Minimize( cp.sum(cp.multiply(P,C)) )
prob = cp.Problem(objective, U)
result = prob.solve()

# %% [markdown]
# Show that $P$ is a binary permutation matrix.

# %%
plt.figure(figsize = (5,5))
plt.imshow(P.value);

# %% [markdown]
# Display the optimal assignement.

# %%
I,J = np.nonzero(P.value>1e-5)
plt.figure(figsize = (10,7))
plt.axis('off')
for k in range(len(I)):
    h = plt.plot(np.hstack((X[0,I[k]],Y[0,J[k]])),np.hstack(([X[1,I[k]], Y[1,J[k]]])),'k', lw = 2)
myplot(X[0,:], X[1,:], 10, 'b')
myplot(Y[0,:], Y[1,:], 10, 'r')
plt.xlim(np.min(Y[0,:])-.1,np.max(Y[0,:])+.1)
plt.ylim(np.min(Y[1,:])-.1,np.max(Y[1,:])+.1)
plt.show()

# %% [raw]
# <script>
#   $(document).ready(function(){
#       $('div.prompt').hide();
#   });
# </script>

# %% [markdown]
# # Personal Experiments

# %% [markdown]
# We will use data from the World Cities Database available at https://simplemaps.com/data/world-cities
#
# This dataset contains lat/long positions for 12959 cities in the world. We can thus use it to model realistic problem.
#
# We will perform two experiments:
#
# - Optimal assignment (Monge Problem). The dataset includes 57 cities in France. We will imagine the following experiments: the mayors from the 57 cities wants to meet the mayors from the 19 biggest cities in Spain, England and Germany. We want to find the optimal transport plan for the french mayors that minimize the total distance. This is an optimal assignment problem since m = 19*3 = 57 = n.
#
# - Kantorovich problem. Instead of making mayors travel we want to send ressources from the 50 biggest cities in france to the 30 biggest cities Spain, Germany and England

# %% [markdown]
# ## Optimal Assignment

# %% [markdown]
# ### Get Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cp

# %%
df = pd.read_csv("worldcities.csv")
print(len(df))
df.head()
# Out:
# 12959
#           city   city_ascii      lat      lng country iso2 iso3   admin_name  \
# 0    Malishevë    Malisheve  42.4822  20.7458  Kosovo   XK  XKS    Malishevë
# 1      Prizren      Prizren  42.2139  20.7397  Kosovo   XK  XKS      Prizren
# 2  Zubin Potok  Zubin Potok  42.9144  20.6897  Kosovo   XK  XKS  Zubin Potok
# 3     Kamenicë     Kamenice  42.5781  21.5803  Kosovo   XK  XKS     Kamenicë
# 4         Viti         Viti  42.3214  21.3583  Kosovo   XK  XKS         Viti
#
#   capital  population          id
# 0   admin         NaN  1901597212
# 1   admin         NaN  1901360309
# 2   admin         NaN  1901608808
# 3   admin         NaN  1901851592
# 4   admin         NaN  1901328795

# %%
# Get the cities from France and the 58 biggest cities in the US
n = 57
df_FR = df[df.iso2=="FR"].sort_values("population").iloc[-n:,:].sample(frac=1)
df_DE = df[df.iso2=="DE"].sort_values("population", ascending=False).iloc[:n//3,:].sample(frac=1)
df_ES = df[df.iso2=="ES"].sort_values("population", ascending=False).iloc[:n//3,:].sample(frac=1)
df_GB = df[df.iso2=="GB"].sort_values("population", ascending=False).iloc[:n//3,:].sample(frac=1)


df_FR.index = df_FR.city_ascii
df_FR = df_FR[["lng","lat"]]
df_DE.index = df_DE.city_ascii
df_DE = df_DE[["lng","lat"]]
df_ES.index = df_ES.city_ascii
df_ES = df_ES[["lng","lat"]]
df_GB.index = df_GB.city_ascii
df_GB = df_GB[["lng","lat"]]

X = df_FR.values.T
Y = np.hstack([df_DE.values.T,df_ES.values.T,df_GB.values.T])

Y.shape
# Out:
# (2, 57)

# %% [markdown]
# ### Helper functions

# %%
# Build the cost matrix
from math import sin, cos, sqrt, atan2, radians

def get_distance_from_lat_long(arr1, arr2):
    '''From two arrays of long/lat coordinates return their pairwise distance in kilometers'''
    
    # approximate radius of earth in km
    R = 6373.0
    n = arr1.shape[1]
    m = arr2.shape[1]
    distance_mat = np.zeros((n,m))
    
    for i in range(n):
        for j in range(m):
            
            lat1, lon1, lat2, lon2 = map(radians, [arr1[1,i], arr1[0,i], arr2[1,j], arr2[0,j]])
            
            dlon = lon2 - lon1
            dlat = lat2 - lat1

            a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
            c = 2 * atan2(sqrt(a), sqrt(1 - a))

            distance = R * c
            distance_mat[i,j] = distance
            
    return distance_mat

# %%
def is_permuation_matrix(x):
    x = np.asanyarray(x)
    return (x.ndim == 2 and x.shape[0] == x.shape[1] and
            (x.sum(axis=0) == 1).all() and 
            (x.sum(axis=1) == 1).all() and
            ((x == 1) | (x == 0)).all())

# %%
myplot = lambda x,y,ms,col: plt.scatter(x,y, s=ms*20, edgecolors="k", c=col, linewidths=2)

# %%
def plot_map(X,Y, P=None):
    plt.figure(figsize = (12,9))
    plt.axis('off')
    
    if type(P)==cp.expressions.variable.Variable:
        I,J = np.nonzero(P.value>1e-5)
        for k in range(len(I)):
            h = plt.plot(np.hstack((X[0,I[k]],Y[0,J[k]])),np.hstack(([X[1,I[k]], Y[1,J[k]]])),'k', lw = 2)

    myplot(X[0,:],X[1,:],5,'b')
    myplot(Y[0,:],Y[1,:],5,'r')
    plt.xlim(min(np.min(Y[0,:]), np.min(X[0,:]))-10 ,max(np.max(Y[0,:]), np.max(X[0,:]))+10)
    plt.ylim(min(np.min(Y[1,:]), np.min(X[1,:]))-1 ,max(np.max(Y[1,:]), np.max(X[1,:]))+1)
    plt.show()

# %%
def plot_map_unbalanced(X,Y,a,b, P=None):
    plt.figure(figsize = (12,9))
    plt.axis('off')
    scale = 10
    X = X*4
    Y = Y*4
    
    if type(P)==cp.expressions.variable.Variable:
        I,J = np.nonzero(P.value>1e-5)  
        for k in range(len(I)):
            h = plt.plot(np.hstack((X[0,I[k]],Y[0,J[k]])),np.hstack(([X[1,I[k]], Y[1,J[k]]])),'k', lw = 2)

    for i in range(len(a)):
        myplot(X[0,i], X[1,i], a[i]*len(a)*10, 'b')
    for j in range(len(b)):
        myplot(Y[0,j], Y[1,j], b[j]*len(b)*10, 'r')
    plt.xlim(min(np.min(Y[0,:]), np.min(X[0,:]))-10 ,max(np.max(Y[0,:]), np.max(X[0,:]))+10)
    plt.ylim(min(np.min(Y[1,:]), np.min(X[1,:]))-10 ,max(np.max(Y[1,:]), np.max(X[1,:]))+10)
    plt.show()

# %%
def plot_interpolate(X,Y,P):
    I,J = np.nonzero(P.value>1e-5)
    Pij = P.value[I,J]

    plt.figure(figsize =(20,20))
    tlist = np.linspace(0, 1, 6)
    for i in range(len(tlist)):
        t = tlist[i]
        Xt = (1-t)*X[:,I] + t*Y[:,J]
        plt.subplot(3,2,i+1)
        plt.axis("off")
        for j in range(len(Pij)):
            myplot(Xt[0,j],Xt[1,j],Pij[j]*len(Pij)*6,[[t,0,1-t]])
        plt.title("t = %.1f" %t) 
        plt.xlim(min(np.min(Y[0,:]), np.min(X[0,:]))-10 ,max(np.max(Y[0,:]), np.max(X[0,:]))+10)
        plt.ylim(min(np.min(Y[1,:]), np.min(X[1,:]))-10 ,max(np.max(Y[1,:]), np.max(X[1,:]))+10)
    plt.show()

# %% [markdown]
# ### Cost matrix

# %%
plot_map(X,Y)

# %%
C = get_distance_from_lat_long(X, Y)
print(C.shape)

# normalize cost matrix
#C = (C.max()-C)/(C.max() - C.min())

# get weights
a = np.ones([n,1])/n
b = a
# Out:
# (57, 57)

# %%
#(i,j) = np.unravel_index(C.argmin(), (n,n))
#print("Closest cities: {}-{}".format(df_FR.iloc[i,:].name,df_US.iloc[j,:].name))

#(i,j) = np.unravel_index(C.argmax(), (n,n))
#print("Farest cities: {}-{}".format(df_FR.iloc[i,:].name,df_US.iloc[j,:].name))

# %% [markdown]
# ### Solve

# %%
#print(cp.installed_solvers())
P = cp.Variable((n,n))
u = np.ones((n,1))
v = np.ones((n,1))
U = [0 <= P, cp.matmul(P,u)==a, cp.matmul(P.T,v)==b]
objective = cp.Minimize( cp.sum(cp.multiply(P,C)) )
prob = cp.Problem(objective, U)
result = prob.solve(verbose=True, eps_abs=1e-10, eps_rel=1e-10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eafac4f3036e> in <module>
#       1 #print(cp.installed_solvers())
# ----> 2 P = cp.Variable((n,n))
#       3 u = np.ones((n,1))
#       4 v = np.ones((n,1))
#       5 U = [0 <= P, cp.matmul(P,u)==a, cp.matmul(P.T,v)==b]
#
# NameError: name 'cp' is not defined

# %% [markdown]
# ### Visualise Restults

# %%
plt.figure(figsize = (5,5))
plt.imshow(P.value); 
for i in range(P.value.shape[0]):
    if (P.value[i,:]>10e-8).sum()!=1:
        print("More than one significant element on row {} in P".format(i))

# %%
# We check that P is indeed a Permutation matrix
P.value[P.value>10e-5]=1
P.value[P.value<=10e-5]=0
is_permuation_matrix(P.value)
# Out:
# True

# %%
plot_map(X,Y,P)

# %% [markdown]
# We see that no optimal transport line are crossing, as expected. But could have seen some lines crossing due to the fact that we used linear interpolation with georaphic coordinates instead of using spherical interpolation.

# %% [markdown]
# ## Kantorovic Problem

# %%
# Get the cities from France and the 58 biggest cities in the US
n = 50
m = 90
df_FR = df[df.iso2=="FR"].sort_values("population").iloc[-n:,:].sample(frac=1)
df_DE = df[df.iso2=="DE"].sort_values("population", ascending=False).iloc[:m//3,:]
df_ES = df[df.iso2=="ES"].sort_values("population", ascending=False).iloc[:m//3,:]
df_GB = df[df.iso2=="GB"].sort_values("population", ascending=False).iloc[:m//3,:]

df_FR.index = df_FR.city_ascii
df_FR = df_FR[["lng","lat"]]
df_DE.index = df_DE.city_ascii
df_DE = df_DE[["lng","lat"]]
df_ES.index = df_ES.city_ascii
df_ES = df_ES[["lng","lat"]]
df_GB.index = df_GB.city_ascii
df_GB = df_GB[["lng","lat"]]

X = df_FR.values.T
Y = np.hstack([df_DE.values.T,df_ES.values.T,df_GB.values.T])


normalize = lambda a: a/np.sum(a)
a = normalize(np.random.rand(n, 1))
b = np.random.rand(m//3, 1)
b = normalize(np.tile(np.sort(b).reshape(-1)[::-1],3)).reshape(-1,1)

# %%
plot_map_unbalanced(X,Y,a,b)

# %%
C = get_distance_from_lat_long(X, Y)
print(C.shape)
# Out:
# (50, 90)

# %%
P = cp.Variable((n,m))
u = np.ones((m,1))
v = np.ones((n,1))
U = [0 <= P, cp.matmul(P,u)==a, cp.matmul(P.T,v)==b]
objective = cp.Minimize( cp.sum(cp.multiply(P,C)) )
prob = cp.Problem(objective, U)
result = prob.solve(verbose=True)
# Out:
# -----------------------------------------------------------------
#            OSQP v0.6.0  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2019
# -----------------------------------------------------------------
# problem:  variables n = 4500, constraints m = 4640
#           nnz(P) + nnz(A) = 13500
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.0953e+06   2.70e+00   1.77e+04   1.00e-01   6.13e-03s
#  200   5.9053e+02   1.04e-04   2.62e+00   4.20e+00   2.67e-02s
#  400   5.8778e+02   1.81e-05   1.40e+00   4.20e+00   5.79e-02s
#  600   5.8777e+02   9.32e-06   6.32e-01   4.20e+00   7.64e-02s
#  800   5.8705e+02   8.00e-06   2.40e-01   4.20e+00   9.44e-02s
# 1000   5.8741e+02   1.06e-05   1.56e-01   4.20e+00   1.12e-01s
# 1200   5.8734e+02   3.42e-06   1.31e-01   4.20e+00   1.30e-01s
# 1400   5.8743e+02   3.54e-06   8.74e-02   4.20e+00   1.48e-01s
# 1600   5.8738e+02   3.74e-06   7.87e-02   4.20e+00   1.66e-01s
# 1800   5.8749e+02   3.29e-06   8.20e-02   4.20e+00   1.84e-01s
# 2000   5.8728e+02   3.42e-06   8.52e-02   4.20e+00   2.03e-01s
# 2200   5.8740e+02   3.70e-06   4.65e-02   4.20e+00   2.21e-01s
# 2400   5.8727e+02   3.32e-06   5.61e-02   4.20e+00   2.39e-01s
# 2600   5.8742e+02   3.26e-06   2.80e-02   4.20e+00   2.57e-01s
#
# status:               solved
# solution polish:      unsuccessful
# number of iterations: 2600
# optimal objective:    587.4189
# run time:             2.63e-01s
# optimal rho estimate: 1.33e+01

# %%
print("Number of non-zero: %d (n + m-1 = %d)" %(len(P.value[P.value>1e-5]), n + m-1))
# Out:
# Number of non-zero: 147 (n + m-1 = 139)

# %%
plt.figure(figsize = (5,5))
plt.imshow(P.value);

# %%
plot_interpolate(X,Y,P)

# %%
plot_map_unbalanced(X,Y,a,b,P)
